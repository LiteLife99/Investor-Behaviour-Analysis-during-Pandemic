# %%
# !pip install nsepy
# Out:
# ...
#   Running setup.py install for nsepy: started
#     Running setup.py install for nsepy: finished with status 'done'
# ...
# WARNING: You are using pip version 19.2.3, however version 20.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import pandas as pd
from datetime import date
from nsepy import get_history

# %%
#reading the NSE firms file
NSEfirms = pd.read_csv('NSEfirms.csv')
NSEfirms.head()
# Out:
#    KZ Index  sa_finance1_cocode              sa_company_name  \
# 0  0.587020                  11              20 MICRONS LTD.
# 1 -5.101258                3335  A V T NATURAL PRODUCTS LTD.
# 2  0.910863                3990             AARTI DRUGS LTD.
# 3  0.313904                3998        AARTI INDUSTRIES LTD.
# 4 -0.161503                4671          RADICO KHAITAN LTD.
#
#                         Ownership  NSE symbol
# 0                Private (Indian)   20MICRONS
# 1               A.V. Thomas Group      AVTNPL
# 2                  Alchemie Group  AARTIDRUGS
# 3                  Alchemie Group    AARTIIND
# 4  Radico (Gajanan Khaitan) Group      RADICO

# %% [markdown]
# # Trial with my own list

# %%
#df = pd.DataFrame(columns=['Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#       'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
 #      '%Deliverble'])
    
df = pd.DataFrame()

# %%
mylist = ['SBIN','ASHIANA','RADICO']

# %%
#looping through the list and appending to dataframe
df1 = get_history(symbol=mylist[0],start=date(2020,1,1),end=date(2020,1,3))
df1.reset_index(level=0, inplace=True)

# %%
for i in range(1, len(mylist)):
    result = get_history(symbol=mylist[i],start=date(2020,1,1),end=date(2020,1,3))
    result.reset_index(level=0, inplace=True)
    print(result)
    df1 = df1.append(result,ignore_index=True)
# Out:
#          Date   Symbol Series  Prev Close    Open    High     Low   Last  \
# 0  2020-01-01  ASHIANA     EQ       102.0  102.05  103.50   97.65   99.9
# 1  2020-01-02  ASHIANA     EQ        99.7  101.30  105.95   98.10  105.0
# 2  2020-01-03  ASHIANA     EQ       104.5  104.05  106.95  103.05  105.7
#
#     Close    VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# 0   99.70   98.93   75553  7.474358e+11    1017               49352
# 1  104.50  101.55  105917  1.075540e+12    1823               77846
# 2  105.85  105.98   27172  2.879733e+11     488               18530
#
#    %Deliverble
# 0       0.6532
# 1       0.7350
# 2       0.6820
#          Date  Symbol Series  Prev Close   Open   High     Low   Last   Close  \
# 0  2020-01-01  RADICO     EQ      313.50  314.8  323.7  312.25  321.0  320.90
# 1  2020-01-02  RADICO     EQ      320.90  321.0  330.0  319.45  325.5  325.45
# 2  2020-01-03  RADICO     EQ      325.45  325.0  326.5  316.25  320.5  319.55
#
# ...

# %%
df1
# Out:
#          Date   Symbol Series  Prev Close    Open    High     Low   Last  \
# 0  2020-01-01     SBIN     EQ      333.75  334.70  335.95  332.15  335.0
# 1  2020-01-02     SBIN     EQ      334.45  334.50  339.85  333.35  338.8
# 2  2020-01-03     SBIN     EQ      339.30  337.95  337.95  332.00  334.0
# 3  2020-01-01  ASHIANA     EQ      102.00  102.05  103.50   97.65   99.9
# 4  2020-01-02  ASHIANA     EQ       99.70  101.30  105.95   98.10  105.0
# 5  2020-01-03  ASHIANA     EQ      104.50  104.05  106.95  103.05  105.7
# 6  2020-01-01   RADICO     EQ      313.50  314.80  323.70  312.25  321.0
# 7  2020-01-02   RADICO     EQ      320.90  321.00  330.00  319.45  325.5
# 8  2020-01-03   RADICO     EQ      325.45  325.00  326.50  316.25  320.5
#
#     Close    VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# 0  334.45  334.03  17379320  5.805130e+14   99108             1850790
# 1  339.30  336.81  20324236  6.845341e+14  123189             4239894
# ...

# %% [markdown]
# # Final testing the companies

# %%
#Make NSE symbols list here
final_list = NSEfirms['NSE symbol']
final_list
# Out:
# 0       20MICRONS
# 1          AVTNPL
# 2      AARTIDRUGS
# 3        AARTIIND
# 4          RADICO
#           ...
# 534      ACCURACY
# 535    ORIENTELEC
# 536       SHRENIK
# 537       MPTODAY
# 538          AISL
# Name: NSE symbol, Length: 539, dtype: object

# %%
df_test = get_history(symbol=final_list[0],start=date(2020,1,1),end=date(2020,6,30))
df_test.reset_index(level=0, inplace=True)

# %%
df_test
# Out:
#            Date     Symbol Series  Prev Close   Open   High    Low   Last  \
# 0    2020-01-01  20MICRONS     EQ       35.20  36.00  36.80  35.25  35.65
# 1    2020-01-02  20MICRONS     EQ       35.80  36.00  36.20  35.10  35.80
# 2    2020-01-03  20MICRONS     EQ       35.55  35.85  35.85  34.95  35.20
# 3    2020-01-06  20MICRONS     EQ       35.05  35.50  35.50  32.20  34.10
# 4    2020-01-07  20MICRONS     EQ       32.80  32.35  34.80  32.35  33.30
# ..          ...        ...    ...         ...    ...    ...    ...    ...
# 118  2020-06-24  20MICRONS     EQ       34.05  35.30  35.30  32.00  32.40
# 119  2020-06-25  20MICRONS     EQ       32.25  32.00  32.15  30.75  31.45
# 120  2020-06-26  20MICRONS     EQ       31.35  31.80  33.00  31.60  32.75
# 121  2020-06-29  20MICRONS     EQ       32.30  33.00  35.00  32.40  34.30
# 122  2020-06-30  20MICRONS     EQ       34.45  34.70  35.10  32.00  33.25
#
#      Close   VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# ...

# %%
for i in range(1, 4):
    result = get_history(symbol=final_list[i],start=date(2020,1,1),end=date(2020,6,30))
    result.reset_index(level=0, inplace=True)
    print(result)
    df_test = df_test.append(result,ignore_index=True)
# Out:
#            Date  Symbol Series  Prev Close   Open   High    Low   Last  Close  \
# 0    2020-01-01  AVTNPL     EQ       31.00  30.95  31.95  30.60  31.25  31.50
# 1    2020-01-02  AVTNPL     EQ       31.50  31.75  36.00  31.65  35.25  35.55
# 2    2020-01-03  AVTNPL     EQ       35.55  35.75  35.85  33.55  33.90  34.00
# 3    2020-01-06  AVTNPL     EQ       34.00  34.00  34.00  31.65  32.50  32.35
# 4    2020-01-07  AVTNPL     EQ       32.35  32.60  33.60  32.15  33.40  33.30
# ..          ...     ...    ...         ...    ...    ...    ...    ...    ...
# 118  2020-06-24  AVTNPL     EQ       40.45  40.80  40.80  38.50  39.00  38.70
# 119  2020-06-25  AVTNPL     EQ       38.70  38.70  39.95  38.15  39.65  39.70
# 120  2020-06-26  AVTNPL     EQ       39.70  40.20  42.50  39.25  40.00  39.85
# 121  2020-06-29  AVTNPL     EQ       39.85  40.50  40.75  39.05  39.65  39.50
# 122  2020-06-30  AVTNPL     EQ       39.50  40.40  41.50  39.40  39.50  39.55
#
# ...

# %%
df_test
# Out:
#            Date     Symbol Series  Prev Close    Open    High     Low    Last  \
# 0    2020-01-01  20MICRONS     EQ       35.20   36.00   36.80   35.25   35.65
# 1    2020-01-02  20MICRONS     EQ       35.80   36.00   36.20   35.10   35.80
# 2    2020-01-03  20MICRONS     EQ       35.55   35.85   35.85   34.95   35.20
# 3    2020-01-06  20MICRONS     EQ       35.05   35.50   35.50   32.20   34.10
# 4    2020-01-07  20MICRONS     EQ       32.80   32.35   34.80   32.35   33.30
# ..          ...        ...    ...         ...     ...     ...     ...     ...
# 487  2020-06-24   AARTIIND     EQ      969.60  968.40  968.80  923.30  946.50
# 488  2020-06-25   AARTIIND     EQ      941.45  941.00  968.40  916.00  959.95
# 489  2020-06-26   AARTIIND     EQ      950.65  968.40  969.95  945.00  945.00
# 490  2020-06-29   AARTIIND     EQ      953.70  944.50  948.40  921.65  925.00
# 491  2020-06-30   AARTIIND     EQ      924.55  933.00  937.00  915.00  936.00
#
# ...

# %% [markdown]
# # Testing successful, now final code

# %%
df_final = get_history(symbol=final_list[0],start=date(2020,1,1),end=date(2020,6,30))
df_final.reset_index(level=0, inplace=True)

# %%
for i in range(1, len(final_list)):
    result = get_history(symbol=final_list[i],start=date(2020,1,1),end=date(2020,6,30))
    result.reset_index(level=0, inplace=True)
    print(result)
    df_final = df_final.append(result,ignore_index=True)
# Out:
#            Date  Symbol Series  Prev Close   Open   High    Low   Last  Close  \
# 0    2020-01-01  AVTNPL     EQ       31.00  30.95  31.95  30.60  31.25  31.50
# 1    2020-01-02  AVTNPL     EQ       31.50  31.75  36.00  31.65  35.25  35.55
# 2    2020-01-03  AVTNPL     EQ       35.55  35.75  35.85  33.55  33.90  34.00
# 3    2020-01-06  AVTNPL     EQ       34.00  34.00  34.00  31.65  32.50  32.35
# 4    2020-01-07  AVTNPL     EQ       32.35  32.60  33.60  32.15  33.40  33.30
# ..          ...     ...    ...         ...    ...    ...    ...    ...    ...
# 118  2020-06-24  AVTNPL     EQ       40.45  40.80  40.80  38.50  39.00  38.70
# 119  2020-06-25  AVTNPL     EQ       38.70  38.70  39.95  38.15  39.65  39.70
# 120  2020-06-26  AVTNPL     EQ       39.70  40.20  42.50  39.25  40.00  39.85
# 121  2020-06-29  AVTNPL     EQ       39.85  40.50  40.75  39.05  39.65  39.50
# 122  2020-06-30  AVTNPL     EQ       39.50  40.40  41.50  39.40  39.50  39.55
#
# ...

# %%
df_final
# Out:
#              Date     Symbol Series  Prev Close   Open   High    Low   Last  \
# 0      2020-01-01  20MICRONS     EQ       35.20  36.00  36.80  35.25  35.65
# 1      2020-01-02  20MICRONS     EQ       35.80  36.00  36.20  35.10  35.80
# 2      2020-01-03  20MICRONS     EQ       35.55  35.85  35.85  34.95  35.20
# 3      2020-01-06  20MICRONS     EQ       35.05  35.50  35.50  32.20  34.10
# 4      2020-01-07  20MICRONS     EQ       32.80  32.35  34.80  32.35  33.30
# ...           ...        ...    ...         ...    ...    ...    ...    ...
# 58346  2020-06-24    SHRENIK     EQ       31.65  33.20  33.20  32.00  33.20
# 58347  2020-06-25    SHRENIK     EQ       33.20  34.85  34.85  33.15  34.85
# 58348  2020-06-26    SHRENIK     EQ       34.85  36.55  36.55  36.30  36.55
# 58349  2020-06-29    SHRENIK     EQ       36.55  38.35  38.35  37.25  38.35
# 58350  2020-06-30    SHRENIK     EQ       38.35  40.25  40.25  36.45  40.25
#
# ...

# %%
print(len(df_final['Symbol'].unique()))
# Out:
# 488

# %%
df_final.to_csv('stock_data.csv', encoding='utf-8', index=False)

# %% [markdown]
# ## Trying with yahoo finance

# %%
import yfinance as yf

# %%
final_list = NSEfirms['NSE symbol']
final_list
# Out:
# 0       20MICRONS
# 1          AVTNPL
# 2      AARTIDRUGS
# 3        AARTIIND
# 4          RADICO
#           ...
# 534      ACCURACY
# 535    ORIENTELEC
# 536       SHRENIK
# 537       MPTODAY
# 538          AISL
# Name: NSE symbol, Length: 539, dtype: object

# %%
df1 = yf.download(final_list[0], start="2020-01-01", end="2020-06-30")
df1.reset_index(level=0, inplace=True)
df1
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - 20MICRONS: No data found, symbol may be delisted
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
data = yf.download("SPY", start="2020-01-01", end="2020-01-05")
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-12-31  320.529999  322.130005  320.149994  321.859985  318.576508
# 2020-01-02  323.540009  324.890015  322.529999  324.869995  321.555786
# 2020-01-03  321.160004  323.640015  321.100006  322.410004  319.120911
#
#               Volume
# Date
# 2019-12-31  57077300
# 2020-01-02  59151200
# 2020-01-03  77709700

# %% [markdown]
# yfinance attempt 1 failed.

# %%
import re
from io import StringIO
from datetime import datetime, timedelta

import requests
import pandas as pd


class YahooFinanceHistory:
    timeout = 2
    crumb_link = 'https://finance.yahoo.com/quote/{0}/history?p={0}'
    crumble_regex = r'CrumbStore":{"crumb":"(.*?)"}'
    quote_link = 'https://query1.finance.yahoo.com/v7/finance/download/{quote}?period1={dfrom}&period2={dto}&interval=1d&events=history&crumb={crumb}'

    def __init__(self, symbol, days_back=7):
        self.symbol = symbol
        self.session = requests.Session()
        self.dt = timedelta(days=days_back)

    def get_crumb(self):
        response = self.session.get(self.crumb_link.format(self.symbol), timeout=self.timeout)
        response.raise_for_status()
        match = re.search(self.crumble_regex, response.text)
        if not match:
            raise ValueError('Could not get crumb from Yahoo Finance')
        else:
            self.crumb = match.group(1)

    def get_quote(self):
        if not hasattr(self, 'crumb') or len(self.session.cookies) == 0:
            self.get_crumb()
        now = datetime.utcnow()
        dateto = int(now.timestamp())
        datefrom = int((now - self.dt).timestamp())
        url = self.quote_link.format(quote=self.symbol, dfrom=datefrom, dto=dateto, crumb=self.crumb)
        response = self.session.get(url)
        response.raise_for_status()
        return pd.read_csv(StringIO(response.text), parse_dates=['Date'])

# %%
final_list = NSEfirms['NSE symbol']
final_list
# Out:
# 0       20MICRONS
# 1          AVTNPL
# 2      AARTIDRUGS
# 3        AARTIIND
# 4          RADICO
#           ...
# 534      ACCURACY
# 535    ORIENTELEC
# 536       SHRENIK
# 537       MPTODAY
# 538          AISL
# Name: NSE symbol, Length: 539, dtype: object

# %%
df_final = YahooFinanceHistory('MPTODAY', days_back=185).get_quote()
df_final['Name'] = final_list[0]
df_final
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-e887bc324f5a> in <module>
# ----> 1 df_final = YahooFinanceHistory('MPTODAY', days_back=185).get_quote()
#       2 df_final['Name'] = final_list[0]
#       3 df_final
#
# <ipython-input-23-8f1245a81224> in get_quote(self)
#      29     def get_quote(self):
#      30         if not hasattr(self, 'crumb') or len(self.session.cookies) == 0:
# ---> 31             self.get_crumb()
#      32         now = datetime.utcnow()
#      33         dateto = int(now.timestamp())
#
# <ipython-input-23-8f1245a81224> in get_crumb(self)
#      23         match = re.search(self.crumble_regex, response.text)
#      24         if not match:
# ---> 25             raise ValueError('Could not get crumb from Yahoo Finance')
#      26         else:
#      27             self.crumb = match.group(1)
#
# ...

# %%
df = YahooFinanceHistory('AAPL', days_back=185).get_quote()
df['Name'] = "AAPL"
df
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2020-01-02  296.239990  300.600006  295.190002  300.350006  298.829956
# 1   2020-01-03  297.149994  300.579987  296.500000  297.429993  295.924713
# 2   2020-01-06  293.790009  299.959991  292.750000  299.799988  298.282715
# 3   2020-01-07  299.839996  300.899994  297.480011  298.390015  296.879883
# 4   2020-01-08  297.160004  304.440002  297.160004  303.190002  301.655548
# ..         ...         ...         ...         ...         ...         ...
# 122 2020-06-26  364.410004  365.320007  353.019989  353.630005  353.630005
# 123 2020-06-29  353.250000  362.170013  351.279999  361.779999  361.779999
# 124 2020-06-30  360.079987  365.980011  360.000000  364.799988  364.799988
# 125 2020-07-01  365.119995  367.359985  363.910004  364.109985  364.109985
# 126 2020-07-02  367.850006  370.470001  363.640015  364.109985  364.109985
#
#        Volume  Name
# 0    33870100  AAPL
# 1    36580700  AAPL
# ...

# %% [markdown]
# Failed for multiple companies in our list
